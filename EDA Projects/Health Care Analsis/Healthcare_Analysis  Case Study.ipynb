# %% [markdown]
# # **HEALTHCARE CLAIMS ANALYSIS**
#
# ## **Dataset Information:**
# - **Each column provides specific information about the patient, their admission, and the healthcare services provided, making this dataset suitable for various data analysis and modeling tasks in the healthcare domain. Here's a brief explanation of each column in the dataset.**
#
# - Name: This column represents the name of the patient associated with the healthcare record.
# - Age: The age of the patient at the time of admission, expressed in years.
# - Gender: Indicates the gender of the patient, either "Male" or "Female."
# - Blood Type: The patient's blood type, which can be one of the common blood types (e.g., "A+", "O-", etc.).
# - Medical Condition: This column specifies the primary medical condition or diagnosis associated with the patient, such as "Diabetes," "Hypertension," "Asthma," and more.
# - Date of Admission: The date on which the patient was admitted to the healthcare facility.
# - Doctor: The name of the doctor responsible for the patient's care during their admission.
# - Hospital: Identifies the healthcare facility or hospital where the patient was admitted.
# - Insurance Provider: This column indicates the patient's insurance provider, which can be one of several options, including "Aetna," "Blue Cross," "Cigna," "UnitedHealthcare," and "Medicare."
# - Billing Amount: The amount of money billed for the patient's healthcare services during their admission. This is expressed as a floating-point number.
# - Room Number: The room number where the patient was accommodated during their admission.
# - Admission Type: Specifies the type of admission, which can be "Emergency," "Elective," or "Urgent," reflecting the circumstances of the admission.
# - Discharge Date: The date on which the patient was discharged from the healthcare facility, based on the admission date and a random number of days within a realistic range.
# - Medication: Identifies a medication prescribed or administered to the patient during their admission. Examples include "Aspirin," "Ibuprofen," "Penicillin," "Paracetamol," and "Lipitor."
# - Test Results: Describes the results of a medical test conducted during the patient's admission. Possible values include "Normal," "Abnormal," or "Inconclusive," indicating the outcome of the test.

# %%
# import libreraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/healthcare_dataset.csv")

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.shape
# Out:
# (55500, 15)

# %% [markdown]
# ### **Inspect the Data**

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
# Check datatypes
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
# Check null values
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
# Check duplicated values
df.duplicated().sum()
# Out:
# np.int64(534)

# %%
# Check data statistical summary
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %% [markdown]
# ### **Data Cleaning**

# %%
## Dorp duplicated values
df = df.drop_duplicates()

# %%
# Agian check
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (54966, 15)

# %%
## 01. Clean Name Columns
df['Name'] = df['Name'].str.strip().str.title()

# %%
df.sample(3)
# Out:
#                 Name  Age  Gender Blood Type Medical Condition  \
# 18483  Jason Johnson   53    Male         B+           Obesity
# 47746     Mary Burch   77  Female         A-          Diabetes
# 50651     Ray Mclean   36    Male        AB-            Asthma
#
#       Date of Admission            Doctor         Hospital Insurance Provider  \
# 18483        2020-10-09  Jennifer Russell        Lynch PLC         Blue Cross
# 47746        2019-11-09   Jessica Johnson  Henry-Rodriguez   UnitedHealthcare
# 50651        2020-05-01      Carlos Brown       Inc Mccann   UnitedHealthcare
#
#        Billing Amount  Room Number Admission Type Discharge Date  Medication  \
# 18483    39358.841961          149       Elective     2020-10-20     Lipitor
# 47746    23450.709118          477       Elective     2019-12-08     Lipitor
# 50651    11568.814786          355      Emergency     2020-05-16  Penicillin
#
#        Test Results
# 18483        Normal
# 47746        Normal
# 50651  Inconclusive

# %%
## 02. 'Billing Amount'
df.loc[df['Billing Amount']<0, 'Billing Amount'] = df['Billing Amount'].mean()

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  54966.000000    54966.000000  54966.000000
# mean      51.535185    25594.536582    301.124404
# std       19.605661    14162.191537    115.223143
# min       13.000000        9.238787    101.000000
# 25%       35.000000    13326.001350    202.000000
# 50%       52.000000    25544.306284    302.000000
# 75%       68.000000    37819.858159    401.000000
# max       89.000000    52764.276736    500.000000

# %%
## 03. Change 'Date of Admission' and 'Discharge Date' into date data type
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])

# %%
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %%
df.sample(2)
# Out:
#                 Name  Age Gender Blood Type Medical Condition  \
# 29926   Donna Savage   66   Male        AB+      Hypertension
# 33807  Deborah Moore   85   Male         A-            Asthma
#
#       Date of Admission       Doctor                Hospital  \
# 29926        2020-04-13  Gary Glover  Clark, Thomas and Rush
# 33807        2022-09-04   Brian Reed       Villanueva-Hunter
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 29926           Medicare    33170.085052          326         Urgent
# 33807              Aetna    42893.500563          333         Urgent
#
#       Discharge Date Medication  Test Results  Days_of_Stay
# 29926     2020-04-15    Aspirin  Inconclusive             2
# 33807     2022-10-03  Ibuprofen  Inconclusive            29

# %%
# check datatype
df.dtypes
# Out:
# Name                          object
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
## 04. Create column days_of_stay.
df['Days_of_Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days

# %%
## Final cleaning check
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# Days_of_Stay          0
# dtype: int64

# %%
df.shape
# Out:
# (54966, 16)

# %%
final_df = df.copy()

# %%
final_df.sample()
# Out:
#                Name  Age  Gender Blood Type Medical Condition  \
# 20254  Anna Santana   38  Female         O+         Arthritis
#
#       Date of Admission         Doctor       Hospital Insurance Provider  \
# 20254        2019-08-24  William Smith  Group Russell              Aetna
#
#        Billing Amount  Room Number Admission Type Discharge Date Medication  \
# 20254    42378.924176          233         Urgent     2019-09-17    Aspirin
#
#       Test Results  Days_of_Stay Admission_Month
# 20254     Abnormal            24         2019-08

# %% [markdown]
# ### **Data Analysis & Visualization**

# %% [markdown]
# ###  **01. Which medical condition affects the most patients across the network?**

# %%
condition_count = df['Medical Condition'].value_counts()
condition_count
# Out:
# Medical Condition
# Arthritis       9218
# Diabetes        9216
# Hypertension    9151
# Obesity         9146
# Cancer          9140
# Asthma          9095
# Name: count, dtype: int64

# %%
import random
plt.figure(figsize=(8,5))
colors = ['b','g','r','c','m','y']
plt.bar(condition_count.index, condition_count.values, color = random.choice(colors))
plt.title('Patients by Medical Condition')
plt.xlabel('Medical Condition')
plt.ylabel('Number of Patients')
# plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  **02. How is patient age distributed across the network?**

# %%
average_age = final_df['Age'].mean()
average_age
# Out:
# np.float64(51.53518538733035)

# %%
plt.figure(figsize=(8,5))
plt.hist(final_df['Age'], bins = 20, color =random.choice(colors), edgecolor = 'b' )
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Number of Patients')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  **03. How has average treatment cost changed overtime?**

# %%
# Create a column Admission_month
final_df['Admission_Month'] = final_df['Date of Admission'].dt.to_period('M')

# %%
monthly_avg_count = final_df.groupby('Admission_Month')['Billing Amount'].mean()
monthly_avg_count
# Out:
# Admission_Month
# 2019-05    25897.449655
# 2019-06    26324.004064
# 2019-07    25928.602371
# 2019-08    25457.102225
# 2019-09    24915.548929
#                ...
# 2024-01    25836.695757
# 2024-02    25703.588425
# 2024-03    25310.583403
# 2024-04    24930.033214
# 2024-05    25464.902913
# Freq: M, Name: Billing Amount, Length: 61, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.plot(monthly_avg_count.index.astype(str), monthly_avg_count.values,
             color = random.choice(colors), marker ='o', markersize = 3)
plt.title('Average Treatment Cost Over Time (Monthly)')
plt.xlabel('Month')
plt.ylabel('Average Billing Amount')
plt.xticks(rotation =90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  **04. Is there a relationship between pateint age and treatment cost?**

# %%
senior_avg_cost = final_df.loc[final_df['Age']>=60, 'Billing Amount'].mean()
senior_avg_cost
# Out:
# np.float64(25563.587763830074)

# %%
sample_df = final_df.sample(1000, random_state =1)

# %%
plt.figure(figsize=(8,5))
plt.scatter(sample_df['Age'], sample_df['Billing Amount'], color = random.choice(colors), alpha= 0.5, s = 15)
plt.title('Age vs Treatment Cost')
plt.xlabel('Age')
plt.ylabel('Billing Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **05. Which insurance provider covers the most patients?**

# %%
insurance_count = final_df['Insurance Provider'].value_counts()
insurance_count
# Out:
# Insurance Provider
# Cigna               11139
# Medicare            11039
# UnitedHealthcare    11014
# Blue Cross          10952
# Aetna               10822
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(insurance_count.values, labels =insurance_count.index, autopct ='%1.1f%%')
plt.title('Patients Share by Insurance Provider')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Business Questions**
# ### **01. Emergency Department Capacity Planning**
# - **The Hospital management is planning staffing for emergency cases. They want to know how many emergency admissions occurred in each month?**

# %%
final_df['Admission Type'].value_counts()
# Out:
# Admission Type
# Elective     18473
# Urgent       18391
# Emergency    18102
# Name: count, dtype: int64

# %%
emergency_month = (final_df.loc[final_df['Admission Type'] == 'Emergency'].groupby(final_df['Date of Admission'].dt.month).size())
emergency_month
# Out:
# Date of Admission
# 1     1547
# 2     1452
# 3     1528
# 4     1473
# 5     1533
# 6     1483
# 7     1573
# 8     1533
# 9     1500
# 10    1490
# 11    1462
# 12    1528
# dtype: int64

# %% [markdown]
# ### **02. Identify High-cost Patient groups**
#
# - **Scenerio : Hospital finance team wants to identify patients who have unusally high billing amounts so they can review those cases.**

# %%
high_cost_patients = final_df.loc[final_df['Billing Amount']> final_df['Billing Amount'].quantile(0.90)]
high_cost_patients
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 5           Emily Johnson   36    Male         A+            Asthma
# 7      Christina Martinez   20  Female         A+            Cancer
# 8         Jasmine Aguilar   82    Male        AB+            Asthma
# 30        Thomas Martinez   34    Male         B-            Asthma
# 35         David Anderson   25  Female        AB+            Asthma
# ...                   ...  ...     ...        ...               ...
# 55446       Richard Moore   63  Female         B+      Hypertension
# 55465      Amanda Stevens   71  Female         O-            Asthma
# 55467         Sandra Chen   62  Female         B+            Asthma
# 55470         Taylor Best   60    Male         A-            Asthma
# 55479    Michael Santiago   58  Female         B-            Cancer
#
#       Date of Admission             Doctor                     Hospital  \
# 5            2023-12-20      Taylor Newton               Nunez-Humphrey
# ...

# %%
high_cost_patients.shape[0]
# Out:
# 5497

# %% [markdown]
# ### **03. Flagging Emergency Cases with Abnormal Results For Review**
# - **Scenario: Hospital management wants to identify emergency patients whose test results are abnormal so these cases prioritized for reviews.**

# %%
 priority_cases = final_df.loc[(final_df['Test Results']=='Abnormal') & (final_df['Admission Type']== 'Emergency')]
priority_cases
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 12         Connor Hansen   75  Female         A+          Diabetes
# 27     Mr. Kenneth Moore   34  Female         A+          Diabetes
# 38         Nicole Lucero   70  Female         O-          Diabetes
# 51        Stephanie Kent   42  Female         A-            Cancer
# 64          Nancy Glover   58    Male         A-      Hypertension
# ...                  ...  ...     ...        ...               ...
# 55471         Ian Murphy   73  Female         B+      Hypertension
# 55480       Lauren Mills   33  Female         B-          Diabetes
# 55488      Brittney York   43  Female         B-           Obesity
# 55490   Stephanie Oliver   82    Male         B-            Cancer
# 55493       Gloria Bowen   57  Female         B-         Arthritis
#
#       Date of Admission               Doctor                       Hospital  \
# 12           2019-12-12     Kenneth Fletcher      Powers Miller, and Flores
# ...

# %%
priority_cases.shape[0]
# Out:
# 6038
